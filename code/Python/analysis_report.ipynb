# %% [markdown]
# # Isokinetic strength data analysis report

# %% [markdown]
# This notebook contains the data analysis report of the isokinetic strength data from the BaSEIB clinical trial, specially the cases in which a file needed to be exclueded from the analysis or some value corrected.

# %%
# Imports
import numpy as np
from proiks import *

# %% [markdown]
# ## Trunk

# %% [markdown]
# ### 60°/s - 1st eval

# %% [markdown]
# #### Excluded subjects

# %% [markdown]
# ID 060 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/1st_eval/1st_strength_trunk_raw_60g_060.txt"
plot_strength_data(path)

# %% [markdown]
# ID 065 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/1st_eval/1st_strength_trunk_raw_60g_065.txt"
plot_strength_data(path)

# %% [markdown]
# #### Subjects with error

# %% [markdown]
# ID 046 had inverted anatomical position angles

# %%
path = "../../data/raw/trunk/60gs/1st_eval/1st_strength_trunk_raw_60g_046.txt"
plot_strength_data(path)

# %% [markdown]
# These angle values were successfully corrected

# %%
path = "../../data/raw/trunk/60gs/1st_eval/1st_strength_trunk_raw_60g_046_corrected.txt"
plot_strength_data(path)

# %% [markdown]
# ### 60°/s - 2nd eval

# %% [markdown]
# #### Excluded subjects

# %% [markdown]
# ID 045 excluded due to inconsistent test results

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_045.txt"
plot_strength_data(path)

# %% [markdown]
# ID 046 excluded due to inconsistent test results

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_046.txt"
plot_strength_data(path)

# %% [markdown]
# ID 072 excluded due to wrong execution of the test

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_072.txt"
plot_strength_data(path)

# %% [markdown]
# ID 085 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_085.txt"
plot_strength_data(path)

# %% [markdown]
# #### Subjects with error

# %% [markdown]
# ID 001 had the right range of motion, but with wrong angles

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_001.txt"
plot_strength_data(path)

# %% [markdown]
# These angle values were successfully corrected

# %%
path = "../../data/raw/trunk/60gs/2nd_eval/2nd_strength_trunk_raw_60g_001_corrected.txt"
plot_strength_data(path)

# %% [markdown]
# ### 60°/s - 3rd eval

# %% [markdown]
# #### Excluded subjects

# %% [markdown]
# ID 017 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/3rd_eval/3rd_strength_trunk_raw_60g_017.txt"
plot_strength_data(path)

# %% [markdown]
# ### 60°/s - 4th eval

# %% [markdown]
# #### Excluded subjects

# %% [markdown]
# ID 003 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/4th_eval/4th_strength_trunk_raw_60g_003.txt"
plot_strength_data(path)

# %% [markdown]
# ID 017 excluded due to wrong range of motion

# %%
path = "../../data/raw/trunk/60gs/4th_eval/4th_strength_trunk_raw_60g_017.txt"
plot_strength_data(path)
